# %%
from AssistingFunctions import simulate_seasons_conditional, plot_conditional_matrices

# %%
results = simulate_seasons_conditional(
    num_simulations=10000,
    home_team="Man City",
    away_team="Arsenal",
    home_display="Manchester City",
    away_display="Arsenal"
)

# %%
print("Simulations per outcome:")
for k, n in results["n_sims"].items():
    print(f"  {k}: {n:,}")
# Out:
# Simulations per outcome:
#   home_win: 4,777
#   draw: 2,314
#   away_win: 2,909

# %%
plot_conditional_matrices(results)
