# %% [markdown]
# # Premier League Data Update
#
# Run the cell below to:
# 1. Download the latest schedule and season results
# 2. Reconcile any manually-entered patch data
# 3. Check for missing games and prompt you to enter them if needed

# %%
from UpdateFunctions import update_pipeline

update_pipeline()
# Out:
# ...
#    PREMIER LEAGUE DATA UPDATE
# ...
#
# ...
#
#   Reconciling patch...                  ✓  (patch is empty)
#
#   All fixtures up to date. Ready to run the model.
