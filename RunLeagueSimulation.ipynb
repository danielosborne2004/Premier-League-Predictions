# %% [markdown]
# # **Importing packages**

# %%
# datascience necessities
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# statistical / optimisation functions
from scipy.stats import poisson, skellam
from scipy.optimize import root_scalar, minimize_scalar

# ML algorithms 
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# helper functions
from AssistingFunctions import *

# %% [markdown]
# ## **Running Simulation**

# %%
final_table = simulate_seasons(10000)

# %%
plot_final_matrix(final_table)

# %%
df_finish_1st(final_table)
# Out:
#              Team  Winning The League (%)
# 0         Arsenal                   70.75
# 1        Man City                   29.25
# 2  Any other team                    0.00

# %%
df_finish_top4(final_table)
# Out:
#               Team  Finish Top 4 (%)
# 0          Arsenal            100.00
# 1         Man City            100.00
# 2       Man United             77.48
# 3      Aston Villa             62.95
# 4        Liverpool             42.71
# 5          Chelsea              7.97
# 6          Everton              2.90
# 7         Brighton              2.26
# 8        Brentford              2.20
# 9       Sunderland              0.85
# 10     Bournemouth              0.35
# 11          Fulham              0.16
# 12  Crystal Palace              0.11
# 13       Newcastle              0.06
# 14  Any other team              0.00

# %%
df_finish_top5(final_table)
# Out:
#               Team  Finish Top 5 (%)
# 0          Arsenal            100.00
# 1         Man City            100.00
# 2       Man United             91.61
# 3      Aston Villa             85.47
# 4        Liverpool             69.11
# 5          Chelsea             22.36
# 6          Everton              9.34
# 7         Brighton              7.66
# 8        Brentford              7.54
# 9       Sunderland              2.79
# 10     Bournemouth              1.85
# 11          Fulham              1.25
# 12  Crystal Palace              0.73
# 13       Newcastle              0.29
# 14  Any other team              0.00

# %%
df_finish_top10(final_table)
# Out:
#               Team  Finish Top 10 (%)
# 0          Arsenal             100.00
# 1         Man City             100.00
# 2       Man United             100.00
# 3      Aston Villa              99.96
# 4        Liverpool              99.26
# 5          Chelsea              89.93
# 6          Everton              76.46
# 7         Brighton              73.00
# 8        Brentford              72.26
# 9       Sunderland              49.73
# 10     Bournemouth              47.98
# 11          Fulham              38.94
# 12       Newcastle              26.46
# 13  Crystal Palace              25.57
# 14           Leeds               0.43
# 15   Nott'm Forest               0.02
# 16  Any other team               0.00

# %%
df_finish_bottom10(final_table)
# Out:
#               Team  Finish Bottom 10 (%)
# 0        Tottenham                100.00
# 1           Wolves                100.00
# 2         West Ham                100.00
# 3          Burnley                100.00
# 4    Nott'm Forest                 99.98
# 5            Leeds                 99.57
# 6   Crystal Palace                 74.43
# 7        Newcastle                 73.54
# 8           Fulham                 61.06
# 9      Bournemouth                 52.02
# 10      Sunderland                 50.27
# 11       Brentford                 27.74
# 12        Brighton                 27.00
# 13         Everton                 23.54
# 14         Chelsea                 10.07
# 15       Liverpool                  0.74
# 16     Aston Villa                  0.04
# 17  Any other team                  0.00

# %%
df_finish_bottom3(final_table)
# Out:
#              Team  Relegation (%)
# 0          Wolves          100.00
# 1         Burnley           99.98
# 2       Tottenham           52.33
# 3        West Ham           29.95
# 4   Nott'm Forest           13.83
# 5           Leeds            3.88
# 6       Newcastle            0.02
# 7  Crystal Palace            0.01
# 8  Any other team            0.00
